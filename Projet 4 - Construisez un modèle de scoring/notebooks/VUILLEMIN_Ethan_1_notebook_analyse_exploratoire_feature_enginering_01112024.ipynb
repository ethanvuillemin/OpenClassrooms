# %% [markdown]
# # <a id='toc1_'></a>[Projet 4, Partie 1 - Construisez un modèle de scoring](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Projet 4, Partie 1 - Construisez un modèle de scoring](#toc1_)
# - [Installation & Imports des bibliothèques](#toc2_)
# - [Contexte & Objectifs](#toc3_)
# - [Exploratory Data Analysis (EDA)](#toc4_)
#   - [Structure et Aperçu des Données](#toc4_1_)
#     - [Lecture du dataframe](#toc4_1_1_)
#     - [Informations generales](#toc4_1_2_)
#     - [Dtypes](#toc4_1_3_)
#     - [Describe](#toc4_1_4_)
#   - [Valeurs manquantes](#toc4_2_)
#     - [Valeurs manquantes par colonnes](#toc4_2_1_)
#     - [Heatmap des valeurs manquantes](#toc4_2_2_)
#     - [Suppression des colonnes > 40% de missing values](#toc4_2_3_)
#     - [Colonnes sans contexte projet](#toc4_2_4_)
#   - [Correlations](#toc4_3_)
#     - [Matrice de corr](#toc4_3_1_)
#   - [Données Qualitatives](#toc4_4_)
#     - [Type de colonnes](#toc4_4_1_)
#       - [Features binaires](#toc4_4_1_1_)
#       - [Features categorielles](#toc4_4_1_2_)
#   - [Creation de nouvelles variables](#toc4_5_)
#     - [Colonne FLAG](#toc4_5_1_)
#     - [Colonne REGION_SCORE](#toc4_5_2_)
#     - [Colonne AMT](#toc4_5_3_)
#       - [Ratio](#toc4_5_3_1_)
#       - [PCA](#toc4_5_3_2_)
# - [Feature Selection](#toc5_)
#     - [Barplot des correlations avec la colonne TARGET](#toc5_1_1_)
#   - [SelectKBest (f_classif)](#toc5_2_)
# - [Gestion des déséquilibres de classes](#toc6_)
#   - [Distribution de la colonne Target](#toc6_1_)
#   - [Réequilibre des classes](#toc6_2_)
#     - [SMOTE](#toc6_2_1_)
#     - [Ponderation](#toc6_2_2_)
#     - [Ponderation VS SMOTE](#toc6_2_3_)
# - [Benchmark des modeles](#toc7_)
#   - [Choix des metrics](#toc7_1_)
#     - [Tableau comparatif des metrics](#toc7_1_1_)
#   - [Comparatif des modèles avec PyCaret](#toc7_2_)
#     - [Anlayse du meilleur model](#toc7_2_1_)
#     - [Conclusion préliminaire :](#toc7_2_2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc2_'></a>[Installation & Imports des bibliothèques](#toc0_)

# %%
# !pip install uv
# !uv venv venv_projet_4.1 --python 3.11.6

# %%
# Installation des librairies
# !uv pip install pandas matplotlib seaborn
# !uv pip install missingno
# !uv pip install skimpy missingno
# !uv pip install scikit-learn
# !uv pip install pycaret

# %%
# Import des librairies
import pandas as pd # type: ignore
import seaborn as sns
import matplotlib.pyplot as plt # type: ignore
import missingno as msno
from sklearn.feature_selection import SelectKBest, f_classif
import numpy as np

# %matplotlib inline

# %% [markdown]
# # <a id='toc3_'></a>[Contexte & Objectifs](#toc0_)

# %% [markdown]
# Le projet consiste à développer un modèle de scoring de crédit pour une société de crédit à la consommation. L'objectif est de prédire la probabilité de défaut de remboursement d'un emprunteur en se basant sur des informations comme son historique de crédit, ses revenus, etc. Le modèle doit être interprétable, ce qui signifie qu'on doit pouvoir comprendre et expliquer les décisions prises par le modèle. Le problème principal du projet est donc de construire un modèle précis, robuste et interprétable pour évaluer le risque de crédit.
#
# Les données fournie sont plusieurs fichier csv qui s'ordonne de la manière suivante:
#
# ![Architecture des données](https://storage.googleapis.com/kaggle-media/competitions/home-credit/home_credit.png)
#
# Il existe 7 sources de données différentes :
#
# - **application_train/application_test** : données principales d'entrainement et de test contenant des informations sur chaque demande de prêt. Chaque prêt a sa propre ligne et est identifié par la caractéristique `SK_ID_CURR`. Les données d'entraînement contiennent la variable `TARGET` indiquant si le prêt a été remboursé (0) ou non (1).
#
# - **bureau** : données concernant les crédits antérieurs des clients auprès d'autres institutions financières. Chaque crédit antérieur a sa propre ligne dans `bureau`, mais un prêt dans les données d'application peut avoir plusieurs crédits antérieurs.
#
# - **bureau_balance** : données mensuelles concernant les crédits antérieurs présents dans `bureau`. Chaque ligne représente un mois d'un crédit antérieur, et un seul crédit antérieur peut avoir plusieurs lignes, une pour chaque mois de la durée du crédit.
#
# - **previous_application** : données sur les demandes de prêt précédentes faites auprès de Home Credit par des clients ayant des prêts dans les données d'application. Chaque prêt actuel peut avoir plusieurs prêts antérieurs. Chaque demande de prêt antérieure a une ligne unique et est identifiée par la caractéristique `SK_ID_PREV`.
#
# - **POS_CASH_BALANCE** : données mensuelles sur les prêts en point de vente ou en espèces précédemment accordés par Home Credit. Chaque ligne représente un mois d'un prêt en point de vente ou en espèces antérieur, et un prêt unique peut avoir de nombreuses lignes.
#
# - **credit_card_balance** : données mensuelles sur les cartes de crédit précédentes que les clients ont eues avec Home Credit. Chaque ligne est un mois de solde d'une carte de crédit, et une carte de crédit unique peut avoir de nombreuses lignes.
#
# - **installments_payment** : historique des paiements pour les prêts antérieurs chez Home Credit. Il y a une ligne pour chaque paiement effectué et une ligne pour chaque paiement manqué.
#
#
# De plus, nous disposons des définitions de toutes les colonnes (dans le fichier `HomeCredit_columns_description.csv`) ainsi qu’un exemple de fichier de soumission attendu.
#
#
# Nous allons d'abord utiliser les données principales d'entraînement et de test par soucis de simplicité, ce qui nous permettra d’aborder  dans un premier temps le problème plus simplement avant de peut-etre intégrer les autres sources de données.

# %% [markdown]
# # <a id='toc4_'></a>[Exploratory Data Analysis (EDA)](#toc0_)
#
# ![EDA Schema](https://media.geeksforgeeks.org/wp-content/uploads/20240509161456/Steps-for-Performing-Exploratory-Data-Analysis.png)

# %% [markdown]
# ## <a id='toc4_1_'></a>[Structure et Aperçu des Données](#toc0_)

# %% [markdown]
# ### <a id='toc4_1_1_'></a>[Lecture du dataframe](#toc0_)

# %%
df_origin = pd.read_csv('../data/application_train.csv')
df = df_origin.copy()

X_train = df.drop('TARGET', axis=1)
Y_train = df.TARGET

# %% [markdown]
# ### <a id='toc4_1_2_'></a>[Informations generales](#toc0_)

# %%
print(f'Shape du dataframe: {df.shape}\n')
df.info()
# Out:
# Shape du dataframe: (307511, 122)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 122 entries, SK_ID_CURR to AMT_REQ_CREDIT_BUREAU_YEAR
# dtypes: float64(65), int64(41), object(16)
# memory usage: 286.2+ MB

# %% [markdown]
# ### <a id='toc4_1_3_'></a>[Dtypes](#toc0_)

# %%
df.dtypes.value_counts()
# Out:
# float64    65
# int64      41
# object     16
# Name: count, dtype: int64

# %% [markdown]
# ### <a id='toc4_1_4_'></a>[Describe](#toc0_)

# %%
df.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# 50%    5.135310e+05   24903.000000     4.500000e+05
# 75%    8.086500e+05   34596.000000     6.795000e+05
# max    4.050000e+06  258025.500000     4.050000e+06
#
#        REGION_POPULATION_RELATIVE     DAYS_BIRTH  DAYS_EMPLOYED  ...  \
# count               307511.000000  307511.000000  307511.000000  ...
# mean                     0.020868  -16036.995067   63815.045904  ...
# std                      0.013831    4363.988632  141275.766519  ...
# min                      0.000290  -25229.000000  -17912.000000  ...
# 25%                      0.010006  -19682.000000   -2760.000000  ...
# 50%                      0.018850  -15750.000000   -1213.000000  ...
# 75%                      0.028663  -12413.000000    -289.000000  ...
# max                      0.072508   -7489.000000  365243.000000  ...
#
#        FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  \
# count     307511.000000     307511.000000     307511.000000     307511.000000
# mean           0.008130          0.000595          0.000507          0.000335
# std            0.089798          0.024387          0.022518          0.018299
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000          0.000000
# 75%            0.000000          0.000000          0.000000          0.000000
# max            1.000000          1.000000          1.000000          1.000000
#
#        AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# count               265992.000000              265992.000000
# mean                     0.006402                   0.007000
# std                      0.083849                   0.110757
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      0.000000                   0.000000
# max                      4.000000                   9.000000
#
#        AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# count               265992.000000              265992.000000
# mean                     0.034362                   0.267395
# std                      0.204685                   0.916002
# min                      0.000000                   0.000000
# 25%                      0.000000                   0.000000
# 50%                      0.000000                   0.000000
# 75%                      0.000000                   0.000000
# max                      8.000000                  27.000000
#
#        AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# count              265992.000000               265992.000000
# mean                    0.265474                    1.899974
# std                     0.794056                    1.869295
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     0.000000                    1.000000
# 75%                     0.000000                    3.000000
# max                   261.000000                   25.000000
#
# [8 rows x 106 columns]

# %% [markdown]
# ## <a id='toc4_2_'></a>[Valeurs manquantes](#toc0_)

# %% [markdown]
# ### <a id='toc4_2_1_'></a>[Valeurs manquantes par colonnes](#toc0_)

# %%
# Calcul des valeurs manquantes par columns
df.isnull().sum().sort_values(ascending=False)
# Out:
# COMMONAREA_MEDI             214865
# COMMONAREA_AVG              214865
# COMMONAREA_MODE             214865
# NONLIVINGAPARTMENTS_MODE    213514
# NONLIVINGAPARTMENTS_AVG     213514
#                              ...
# NAME_HOUSING_TYPE                0
# NAME_FAMILY_STATUS               0
# NAME_EDUCATION_TYPE              0
# NAME_INCOME_TYPE                 0
# SK_ID_CURR                       0
# Length: 122, dtype: int64

# %%
# Calcul des valeurs manquantes par columns en %
missing_percent_cols = (df.isna().sum() / len(df)) * 100
missing_percent_cols = missing_percent_cols.sort_values(ascending=False)
print(missing_percent_cols)
# Out:
# COMMONAREA_MEDI             69.872297
# COMMONAREA_AVG              69.872297
# COMMONAREA_MODE             69.872297
# NONLIVINGAPARTMENTS_MODE    69.432963
# NONLIVINGAPARTMENTS_AVG     69.432963
#                               ...
# NAME_HOUSING_TYPE            0.000000
# NAME_FAMILY_STATUS           0.000000
# NAME_EDUCATION_TYPE          0.000000
# NAME_INCOME_TYPE             0.000000
# SK_ID_CURR                   0.000000
# Length: 122, dtype: float64

# %%
# nombre de colonnes avec plus de 50% de valeurs manquantes
superior_50_cols = missing_percent_cols[missing_percent_cols > 50]  # noqa: F821
print(f'Colonnes avec plus de 50% de valeurs manquantes: {len(superior_50_cols)}')
# Out:
# Colonnes avec plus de 50% de valeurs manquantes: 41

# %% [markdown]
# ### <a id='toc4_2_2_'></a>[Heatmap des valeurs manquantes](#toc0_)

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.isnull(), cmap='plasma', cbar=False, yticklabels=False)
plt.title('Heatmap des valeurs manquantes', fontsize=16)
plt.show()

# %%
# Clacul du pourcentage general manquant dans le dataframe
total_missing_percent = (df.isna().sum().sum() / df.size) * 100
print(f"Pourcentage de valeurs manquantes dans le DataFrame : {total_missing_percent:.2f}%")
# Out:
# Pourcentage de valeurs manquantes dans le DataFrame : 24.40%

# %% [markdown]
# ### <a id='toc4_2_3_'></a>[Suppression des colonnes > 40% de missing values](#toc0_)

# %%
drop_cols = missing_percent_cols[missing_percent_cols > 40]
df = df.drop(list(drop_cols.index), axis=1)

# %%
# barchart des valeurs manquantes (après traitement)
msno.bar(df)
# Out:
# <Axes: >

# %%
# Clacul du pourcentage general manquant dans le dataframe
total_missing_percent = (df.isna().sum().sum() / df.size) * 100
print(f"Pourcentage de valeurs manquantes dans le DataFrame : {total_missing_percent:.2f}%")
# Out:
# Pourcentage de valeurs manquantes dans le DataFrame : 1.84%

# %% [markdown]
# ### <a id='toc4_2_4_'></a>[Colonnes sans contexte projet](#toc0_)

# %% [markdown]
# Voici les colonnes identifiées comme potentiellement inutiles, car elles ce sont des identifiants ou des informations personnelles qui ne contribuent pas directement à la prédiction de la probabilité de remboursement :
#
# - SK_ID_CURR : Identifiant unique du client.
# - NAME_CONTRACT_TYPE : Type de contrat, souvent fixe et non discriminant dans la prédiction.
# - NAME_TYPE_SUITE : Type de personne accompagnante (non pertinent pour le scoring crédit).
# - NAME_INCOME_TYPE : Source de revenu, souvent redondante avec d'autres variables de revenu.
# - NAME_EDUCATION_TYPE : Niveau d'éducation, peu pertinent dans certains contextes financiers.
# - NAME_FAMILY_STATUS : Statut familial, souvent non corrélé directement au remboursement.
# - NAME_HOUSING_TYPE : Type de logement, peu informatif pour un modèle financier.
# - DAYS_ID_PUBLISH : Date de publication du document, non pertinent pour la prédiction.
# - FLAG_EMP_PHONE : Indique si le téléphone professionnel est fourni, faible valeur prédictive.
# - FLAG_WORK_PHONE : Même remarque que ci-dessus.
# - FLAG_PHONE : Indique si un numéro de téléphone est fourni, souvent inutile.
# - FLAG_EMAIL : Indique si une adresse email est fournie, non pertinent.
# - DAYS_LAST_PHONE_CHANGE : Dernier changement de téléphone, faible lien avec la probabilité de remboursement.

# %%
useless_cols = [
    'SK_ID_CURR',
    'NAME_CONTRACT_TYPE',
    'NAME_TYPE_SUITE',
    'NAME_INCOME_TYPE',
    'NAME_EDUCATION_TYPE',
    'NAME_FAMILY_STATUS',
    'NAME_HOUSING_TYPE',
    'DAYS_ID_PUBLISH',
    'FLAG_EMP_PHONE',
    'FLAG_WORK_PHONE',
    'FLAG_PHONE',
    'FLAG_EMAIL',
    'DAYS_LAST_PHONE_CHANGE',
    'WEEKDAY_APPR_PROCESS_START'
]

df = df.drop(useless_cols, axis=1)

# %% [markdown]
# ## <a id='toc4_3_'></a>[Correlations](#toc0_)

# %% [markdown]
# ### <a id='toc4_3_1_'></a>[Matrice de corr](#toc0_)

# %%
# Liste des colonnes numériques
numerical_columns = list(df.select_dtypes(include="number").columns)
target_column = 'target'  # Remplace 'target' par le nom exact de ta colonne cible

# Étape 1 : Supprimer les colonnes avec une variance nulle (colonnes constantes)
df_filtered = df[numerical_columns].loc[:, df[numerical_columns].std() > 0]

# Étape 2 : Calculer la matrice de corrélation et remplacer les NaN par 0
correlation_matrix = df_filtered.corr().fillna(0)

sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
df.dtypes.value_counts()
# Out:
# int64      35
# float64    19
# object      5
# Name: count, dtype: int64

# %% [markdown]
# ## <a id='toc4_4_'></a>[Données Qualitatives](#toc0_)

# %% [markdown]
# ### <a id='toc4_4_1_'></a>[Type de colonnes](#toc0_)

# %%
# Afficher les colonnes cat
qualitative_columns = list(df.select_dtypes(include='object').columns)
print(qualitative_columns)

df[qualitative_columns].head(10)
# Out:
# ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'OCCUPATION_TYPE', 'ORGANIZATION_TYPE']
#   CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY OCCUPATION_TYPE  \
# 0           M            N               Y        Laborers
# 1           F            N               N      Core staff
# 2           M            Y               Y        Laborers
# 3           F            N               Y        Laborers
# 4           M            N               Y      Core staff
# 5           M            N               Y        Laborers
# 6           F            Y               Y     Accountants
# 7           M            Y               Y        Managers
# 8           F            N               Y             NaN
# 9           M            N               Y        Laborers
#
#         ORGANIZATION_TYPE
# 0  Business Entity Type 3
# 1                  School
# 2              Government
# 3  Business Entity Type 3
# 4                Religion
# 5                   Other
# 6  Business Entity Type 3
# 7                   Other
# 8                     XNA
# 9             Electricity

# %% [markdown]
# #### <a id='toc4_4_1_1_'></a>[Features binaires](#toc0_)

# %%
# Colonne dite a valeurs binaire 
binary_features = [
    'CODE_GENDER',
    'FLAG_OWN_CAR',
    'FLAG_OWN_REALTY'
]

# Verification des valeurs pour chaques colonnes
for col in df[binary_features]:
    print(col, df[col].unique())
# Out:
# CODE_GENDER ['M' 'F' 'XNA']
# FLAG_OWN_CAR ['N' 'Y']
# FLAG_OWN_REALTY ['Y' 'N']

# %%
# Regarder si XNA est une variable a prendre en compte ou non
df['CODE_GENDER'].value_counts()
# Out:
# CODE_GENDER
# F      202448
# M      105059
# XNA         4
# Name: count, dtype: int64

# %%
# Suppression des lignes du df contenant XNA
df['CODE_GENDER'] = df['CODE_GENDER'].where(df['CODE_GENDER'] != 'XNA')
df['CODE_GENDER'].value_counts()
# Out:
# CODE_GENDER
# F    202448
# M    105059
# Name: count, dtype: int64

# %%
# Application de get_dummies sur mes cols
for col in binary_features:
    df[col] = pd.get_dummies(df[col], drop_first=True).astype(int)

df[binary_features]
# Out:
#         CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY
# 0                 1             0                1
# 1                 0             0                0
# 2                 1             1                1
# 3                 0             0                1
# 4                 1             0                1
# ...             ...           ...              ...
# 307506            1             0                0
# 307507            0             0                1
# 307508            0             0                1
# 307509            0             0                1
# 307510            0             0                0
#
# [307511 rows x 3 columns]

# %% [markdown]
# Pour mes colonnes sur lesquelles on ne peut pas appliquer un get dummies on va dans un premier temps regarder leur caractéristique et ensuite trouver la methode adequate

# %%
# Recuperation du nombres de valeurs diff
df['OCCUPATION_TYPE'].unique()
# Out:
# array(['Laborers', 'Core staff', 'Accountants', 'Managers', nan,
#        'Drivers', 'Sales staff', 'Cleaning staff', 'Cooking staff',
#        'Private service staff', 'Medicine staff', 'Security staff',
#        'High skill tech staff', 'Waiters/barmen staff',
#        'Low-skill Laborers', 'Realty agents', 'Secretaries', 'IT staff',
#        'HR staff'], dtype=object)

# %%
# Recuperation du nombres de valeurs diff
df['ORGANIZATION_TYPE'].unique()
# Out:
# array(['Business Entity Type 3', 'School', 'Government', 'Religion',
#        'Other', 'XNA', 'Electricity', 'Medicine',
#        'Business Entity Type 2', 'Self-employed', 'Transport: type 2',
#        'Construction', 'Housing', 'Kindergarten', 'Trade: type 7',
#        'Industry: type 11', 'Military', 'Services', 'Security Ministries',
#        'Transport: type 4', 'Industry: type 1', 'Emergency', 'Security',
#        'Trade: type 2', 'University', 'Transport: type 3', 'Police',
#        'Business Entity Type 1', 'Postal', 'Industry: type 4',
#        'Agriculture', 'Restaurant', 'Culture', 'Hotel',
#        'Industry: type 7', 'Trade: type 3', 'Industry: type 3', 'Bank',
#        'Industry: type 9', 'Insurance', 'Trade: type 6',
#        'Industry: type 2', 'Transport: type 1', 'Industry: type 12',
#        'Mobile', 'Trade: type 1', 'Industry: type 5', 'Industry: type 10',
#        'Legal Services', 'Advertising', 'Trade: type 5', 'Cleaning',
#        'Industry: type 13', 'Trade: type 4', 'Telecom',
#        'Industry: type 8', 'Realtor', 'Industry: type 6'], dtype=object)

# %% [markdown]
# #### <a id='toc4_4_1_2_'></a>[Features categorielles](#toc0_)

# %% [markdown]
# Dans le cas de nos variables categorielle nous aurions pu utiliser one hot encoder mais cela risque d'augmenter la charge computationel et la pertinence de mes colonnes pour ce faire j'utilise la frequency encoding qui consiste à remplacer la valeur categorielle par sa frequence d'appartion dans le dataset
#
# Tous les options envisagé:
# - One Hot Encoder
# - Frequence Encoding
# - Target Encoding
# - Embedding
# - Ordinal Encoding
#
# La methode retenue est le Target Encoding car il permet un remplaement rapide tout en gardant la complexité entre la target et la colonnes target comme l'explicite ce [paper universitaire](https://arxiv.org/pdf/2104.00629)

# %%
# Calcul de la moyenne de la cible pour chaque catégorie
target_mean_organisation_type = df.groupby('ORGANIZATION_TYPE')['TARGET'].mean()

df['ORGANIZATION_TYPE'] = df['ORGANIZATION_TYPE'].map(target_mean_organisation_type)

# Affichage du résultat
print("Train DataFrame with Target Encoding:")
df['ORGANIZATION_TYPE'].head()
# Out:
# Train DataFrame with Target Encoding:
# 0    0.092996
# 1    0.059148
# 2    0.069781
# 3    0.092996
# 4    0.058824
# Name: ORGANIZATION_TYPE, dtype: float64

# %%
# Calcul de la moyenne de la cible pour chaque catégorie
target_mean_organisation_type = df.groupby('OCCUPATION_TYPE')['TARGET'].mean()

df['OCCUPATION_TYPE'] = df['OCCUPATION_TYPE'].map(target_mean_organisation_type)

# Affichage du résultat
print("Train DataFrame with Target Encoding:")
df['OCCUPATION_TYPE'].head()
# Out:
# Train DataFrame with Target Encoding:
# 0    0.105788
# 1    0.063040
# 2    0.105788
# 3    0.105788
# 4    0.063040
# Name: OCCUPATION_TYPE, dtype: float64

# %% [markdown]
# ## <a id='toc4_5_'></a>[Creation de nouvelles variables](#toc0_)

# %%
binary_columns = [
    col for col in df.columns 
    if set(df[col].dropna().unique()).issubset({0, 1}) or set(df[col].dropna().unique()).issubset({'Y', 'N'})
]

print(binary_columns)
# Out:
# ['TARGET', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'FLAG_MOBIL', 'FLAG_CONT_MOBILE', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21']

# %% [markdown]
# ### <a id='toc4_5_1_'></a>[Colonne FLAG](#toc0_)

# %%
# Afficher le type de toutes le colonnes FLAG
print(df.filter(like='FLAG').dtypes)


# Recuperer toutes les colonnes qui sont un FLAG
flags_columns = df.filter(like='FLAG')

# Additionner numeriquement toutes les colonnes pour n'en faire plus qu'une
df['FLAGS'] = df.filter(like='FLAG').sum(axis=1)

# Afficher les information de la colonne crée
df.FLAGS.describe()

#  Supprimer toutes les colonnes flags
df = df.drop(flags_columns, axis=1)
# Out:
# FLAG_OWN_CAR        int32
# FLAG_OWN_REALTY     int32
# FLAG_MOBIL          int64
# FLAG_CONT_MOBILE    int64
# FLAG_DOCUMENT_2     int64
# FLAG_DOCUMENT_3     int64
# FLAG_DOCUMENT_4     int64
# FLAG_DOCUMENT_5     int64
# FLAG_DOCUMENT_6     int64
# FLAG_DOCUMENT_7     int64
# FLAG_DOCUMENT_8     int64
# FLAG_DOCUMENT_9     int64
# FLAG_DOCUMENT_10    int64
# FLAG_DOCUMENT_11    int64
# FLAG_DOCUMENT_12    int64
# FLAG_DOCUMENT_13    int64
# FLAG_DOCUMENT_14    int64
# FLAG_DOCUMENT_15    int64
# FLAG_DOCUMENT_16    int64
# FLAG_DOCUMENT_17    int64
# FLAG_DOCUMENT_18    int64
# FLAG_DOCUMENT_19    int64
# FLAG_DOCUMENT_20    int64
# FLAG_DOCUMENT_21    int64
# dtype: object

# %%
binary_columns = [
    col for col in df.columns 
    if set(df[col].dropna().unique()).issubset({0, 1}) or set(df[col].dropna().unique()).issubset({'Y', 'N'})
]

print(binary_columns)
# Out:
# ['TARGET', 'CODE_GENDER', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY']

# %% [markdown]
# ### <a id='toc4_5_2_'></a>[Colonne REGION_SCORE](#toc0_)

# %%
# Afficher le type de toutes le colonnes FLAG
print(df.filter(like='REGION').dtypes)

#Afficher les informations generales des colonnes clé
df[df.filter(like='REGION').columns].describe()
# Out:
# REGION_POPULATION_RELATIVE     float64
# REGION_RATING_CLIENT             int64
# REGION_RATING_CLIENT_W_CITY      int64
# REG_REGION_NOT_LIVE_REGION       int64
# REG_REGION_NOT_WORK_REGION       int64
# LIVE_REGION_NOT_WORK_REGION      int64
# dtype: object
#        REGION_POPULATION_RELATIVE  REGION_RATING_CLIENT  \
# count               307511.000000         307511.000000
# mean                     0.020868              2.052463
# std                      0.013831              0.509034
# min                      0.000290              1.000000
# 25%                      0.010006              2.000000
# 50%                      0.018850              2.000000
# 75%                      0.028663              2.000000
# max                      0.072508              3.000000
#
#        REGION_RATING_CLIENT_W_CITY  REG_REGION_NOT_LIVE_REGION  \
# count                307511.000000               307511.000000
# mean                      2.031521                    0.015144
# std                       0.502737                    0.122126
# min                       1.000000                    0.000000
# 25%                       2.000000                    0.000000
# 50%                       2.000000                    0.000000
# 75%                       2.000000                    0.000000
# max                       3.000000                    1.000000
#
#        REG_REGION_NOT_WORK_REGION  LIVE_REGION_NOT_WORK_REGION
# count               307511.000000                307511.000000
# mean                     0.050769                     0.040659
# std                      0.219526                     0.197499
# min                      0.000000                     0.000000
# 25%                      0.000000                     0.000000
# 50%                      0.000000                     0.000000
# 75%                      0.000000                     0.000000
# max                      1.000000                     1.000000

# %%
# Récupérer toutes les colonnes qui contiennent 'REGION' dans leur nom
region_columns = list(df.filter(like='REGION').columns)

# Ajouter les autres colonnes relatives au score région
region_columns += ['REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY']

# Afficher la liste finale des colonnes liées à la région
print(region_columns)

# Additionner numeriquement toutes les colonnes pour n'en faire plus qu'une
df['REGION_SCORE'] = df[region_columns].sum(axis=1)

# Afficher les information de la colonne crée
print(df.REGION_SCORE.describe())

#  Supprimer toutes les colonnes regs
df = df.drop(region_columns, axis=1)
# Out:
# ['REGION_POPULATION_RELATIVE', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY']
# count    307511.000000
# mean          4.699605
# std           1.435383
# min           2.003541
# 25%           4.010966
# 50%           4.026392
# 75%           6.010276
# max          12.020713
# Name: REGION_SCORE, dtype: float64

# %% [markdown]
# ### <a id='toc4_5_3_'></a>[Colonne AMT](#toc0_)

# %% [markdown]
# Voici les variables commençant par "AMT" dans le dataset :
# - AMT_INCOME_TOTAL : Revenu total déclaré du client.
# - AMT_CREDIT : Montant total du crédit demandé.
# - AMT_ANNUITY : Montant de l'annuité prévue pour rembourser le crédit.
# - AMT_GOODS_PRICE : Prix des biens financés par le crédit.
# - AMT_REQ_CREDIT_BUREAU_HOUR : Nombre de demandes de crédit faites dans les dernières heures.
# - AMT_REQ_CREDIT_BUREAU_DAY : Nombre de demandes de crédit faites dans la dernière journée.
# - AMT_REQ_CREDIT_BUREAU_WEEK : Nombre de demandes de crédit faites dans la dernière semaine.
# - AMT_REQ_CREDIT_BUREAU_MON : Nombre de demandes de crédit faites dans le dernier mois.
# - AMT_REQ_CREDIT_BUREAU_QRT : Nombre de demandes de crédit faites dans le dernier trimestre.
# - AMT_REQ_CREDIT_BUREAU_YEAR : Nombre de demandes de crédit faites dans la dernière année.

# %%
# Recuperer toutes les colonnes AMT
amt_columns = df.filter(like='AMT').columns

# Afficher les colonnes amt
print(amt_columns)
# Out:
# Index(['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE',
#        'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY',
#        'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON',
#        'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object')

# %% [markdown]
# #### <a id='toc4_5_3_1_'></a>[Ratio](#toc0_)
# Ces ratios aident à capturer des relations relatives entre différentes mesures financières :
#
# - Ratio revenu/crédit → Reflète la proportion de revenu par rapport au montant du crédit.
# - Ratio annuité/crédit → Indique la charge relative de l'annuité par rapport au montant du crédit.
# - Ratio crédit/prix des biens → Montre la proportion financée par le crédit par rapport au prix des biens.
# - Ratio revenu/annuité → Évalue combien de fois le revenu peut couvrir l'annuité.

# %%
# Retio revenu global / credit 
df['INCOME_CREDIT_RATIO'] = df['AMT_INCOME_TOTAL'] / df['AMT_CREDIT']

# Ratio Anuité credit
df['ANNUITY_CREDIT_RATIO'] = df['AMT_ANNUITY'] / df['AMT_CREDIT']

# Ratio crédit / prix des biens posseder
df['CREDIT_POSSESION_RATIO'] = df['AMT_CREDIT'] / df['AMT_GOODS_PRICE']

# Ratio Anuité / revenu
df['INCOME_ANNUITY_RATIO'] = df['AMT_INCOME_TOTAL'] / df['AMT_ANNUITY']

# %% [markdown]
# #### <a id='toc4_5_3_2_'></a>[PCA](#toc0_)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Verification des valeurs manquantes
print(df[amt_columns].isna().sum())
df = df.dropna()

# Normalisation des données
scaler = StandardScaler()
amount_scaled = scaler.fit_transform(df[amt_columns])

# Application de la PCA
pca = PCA(n_components=1)
df['AMT_PCA'] = pca.fit_transform(amount_scaled)
# Out:
# AMT_INCOME_TOTAL                  0
# AMT_CREDIT                        0
# AMT_ANNUITY                      12
# AMT_GOODS_PRICE                 278
# AMT_REQ_CREDIT_BUREAU_HOUR    41519
# AMT_REQ_CREDIT_BUREAU_DAY     41519
# AMT_REQ_CREDIT_BUREAU_WEEK    41519
# AMT_REQ_CREDIT_BUREAU_MON     41519
# AMT_REQ_CREDIT_BUREAU_QRT     41519
# AMT_REQ_CREDIT_BUREAU_YEAR    41519
# dtype: int64

# %%
# Supression des colonnes AMT
df = df.drop(amt_columns, axis=1)

# %% [markdown]
# # <a id='toc5_'></a>[Feature Selection](#toc0_)

# %% [markdown]
# Maintenant que toutes mes colonnes sont des colonnes numerique je peux à présent utiliser des algorithmes de feature selection afin d'etre plus pertinent dans le choix de mes colonnes, et ainsi avoir de meilleur resultat pour mon futur modèle

# %% [markdown]
# ### <a id='toc5_1_1_'></a>[Barplot des correlations avec la colonne TARGET](#toc0_)

# %%
target_column = 'TARGET'
numerical_columns = list(df.select_dtypes(include="number").columns)
# Calculer les corrélations entre chaque colonne numérique et la cible
correlations = df[numerical_columns].corr()[target_column].drop(target_column)

# Trier les corrélations par ordre décroissant
correlations = correlations.sort_values(ascending=False)

# Afficher les corrélations avec un graphique en barres
plt.figure(figsize=(25, 20))
sns.barplot(x=correlations.values, y=correlations.index, palette='viridis')
plt.title(f'Corrélations des colonnes avec {target_column}', fontsize=32)
plt.xlabel('Coefficient de corrélation')
plt.show()

# %%
# Suppression des lignes contenant des NAN
df = df.dropna()

# Define X, Y
X = df.drop('TARGET', axis=1)
Y = df.TARGET

# %% [markdown]
# ## <a id='toc5_2_'></a>[SelectKBest (f_classif)](#toc0_)

# %%
# Sélectionner les meilleures features
num_selector = SelectKBest(score_func=f_classif, k='all').fit(X, Y)

# Scores numériques
scores = num_selector.scores_

# Créer un dataframe pour seaborn
feature_scores = pd.DataFrame({
    'Feature': np.array(X.columns),
    'Score': scores
})

# %%
# Trier les scores par ordre décroissant
feature_scores = feature_scores.sort_values(by='Score', ascending=False)

# Créer un graphique avec seaborn
plt.figure(figsize=(15, 11))
sns.barplot(x='Score', y='Feature', data=feature_scores[:15])
plt.title('Scores des Features avec SelectKBest (f_classif)')
plt.show()

# %% [markdown]
# # <a id='toc6_'></a>[Gestion des déséquilibres de classes](#toc0_)

# %% [markdown]
# ## <a id='toc6_1_'></a>[Distribution de la colonne Target](#toc0_)

# %%
# Display percentage of each value
print(Y_train.value_counts(), Y_train.value_counts(normalize=True))
# Out:
# TARGET
# 0    282686
# 1     24825
# Name: count, dtype: int64 TARGET
# 0    0.919271
# 1    0.080729
# Name: proportion, dtype: float64

# %%
pie_chart_values = Y_train.value_counts()
sns.set_style("whitegrid")
plt.figure(figsize=(8,8))
plt.pie(pie_chart_values, labels=pie_chart_values.index, autopct='%1.1f%%')
plt.title('Distribution de la colonne TARGET')
plt.show()

# %% [markdown]
# On peut voir ici que notre TARGET est très hétérogène, c'est-à-dire que sur deux classe présente ici 0 et 1 il y a la classe 0 qui est présente a plus de 90 %, ce qui n'est pas le plus optimal pour pouvoir entraîner notre modèle par la suite, il faudra donc équilibrer les classes avant de pouvoir entraîner le modèle sous peine de le fausser.

# %% [markdown]
# ## <a id='toc6_2_'></a>[Réequilibre des classes](#toc0_)

# %%
# Suppression des lignes contenant des NAN
df = df.dropna()

# Define X, Y
X = df.drop('TARGET', axis=1)
Y = df.TARGET

print(X.shape, Y.shape)
# Out:
# (168317, 22) (168317,)

# %% [markdown]
# ### <a id='toc6_2_1_'></a>[SMOTE](#toc0_)

# %%
from imblearn.over_sampling import SMOTE

# Initialise Smote
smote = SMOTE()

# Do the resample
X_resampled, y_resampled = smote.fit_resample(X, Y)

print(X_resampled.shape, y_resampled.shape)
# Out:
# (308164, 22) (308164,)

# %%
# Plot a pie chart after applying SMOTE
pie_chart_values = y_resampled.value_counts()
sns.set_style("whitegrid")
plt.figure(figsize=(8,8))
plt.pie(pie_chart_values, labels=pie_chart_values.index, autopct='%1.1f%%')
plt.title('Distribution de la colonne TARGET')
plt.show()

# %% [markdown]
# ### <a id='toc6_2_2_'></a>[Ponderation](#toc0_)

# %% [markdown]
# Augmenter le poid de la classe minoritaire, peut etre fait en utilisant l'argument class_weight de sklearn

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(class_weight='balanced')

# %% [markdown]
# ### <a id='toc6_2_3_'></a>[Ponderation VS SMOTE](#toc0_)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# Modèle avec pondération
model_weighted = RandomForestClassifier(class_weight='balanced', random_state=42)

# Cross-validation
scores_weighted = cross_val_score(model_weighted, X, Y, scoring='roc_auc', cv=5)
print(f"AUC moyenne (pondération) : {scores_weighted.mean():.4f}")
# Out:
# AUC moyenne (pondération) : 0.7277

# %%
from imblearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# Pipeline avec SMOTE
model_smote = Pipeline([
    ('smote', SMOTE(random_state=42, k_neighbors=5)),
    ('classifier', RandomForestClassifier(random_state=42))])

# Validation croisée
scores_smote = cross_val_score(model_smote, X, Y, scoring='roc_auc', cv=5)
print(f"AUC moyenne (SMOTE) : {scores_smote.mean():.4f}")
# Out:
# AUC moyenne (SMOTE) : 0.7032

# %%
print(f"AUC moyenne (pondération) : {scores_weighted.mean():.4f} \nAUC moyenne (SMOTE) : {scores_smote.mean():.4f}")
# Out:
# AUC moyenne (pondération) : 0.7277
# AUC moyenne (SMOTE) : 0.7032

# %% [markdown]
# Le choix de la ponderation est plus pertinent dans notre contexte projet nous allons donc quand c'est possible priviligié cette methode

# %% [markdown]
# # <a id='toc7_'></a>[Benchmark des modeles](#toc0_)

# %% [markdown]
# ## <a id='toc7_1_'></a>[Choix des metrics](#toc0_)

# %% [markdown]
# ### <a id='toc7_1_1_'></a>[Tableau comparatif des metrics](#toc0_)
#
# | **Métrique**   | **Utilité**                                                                 | **Fonctionnement**                                                                                                                                           | **Cas d'utilisation**                                                                                   | **Valeurs**                     |
# |----------------|-----------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------|----------------------------------|
# | **Accuracy**   | Évaluer la proportion de bonnes prédictions globales.                      | Ratio des prédictions correctes sur le total des prédictions.                                                                                                | Quand les classes sont équilibrées (peu ou pas de déséquilibre).                                         | Bonne : proche de 1 <br> Mauvaise : proche de 0 |
# | **AUC**        | Mesurer la capacité d'un modèle à séparer les classes.                     | Aire sous la courbe ROC (trade-off entre sensibilité et spécificité pour différents seuils).                                                                  | Pour évaluer les performances sur des données déséquilibrées.                                           | Bonne : proche de 1 <br> Mauvaise : proche de 0 |
# | **Recall**     | Mesurer la capacité à détecter les vrais positifs.                         | Calculé comme : `TP / (TP + FN)` (positifs correctement prédits sur tous les positifs réels).                                                                 | Quand détecter les vrais positifs est critique (ex. dépistage médical).                                 | Bonne : proche de 1 <br> Mauvaise : proche de 0 |
# | **Precision**  | Mesurer la fiabilité des prédictions positives.                            | Calculé comme : `TP / (TP + FP)` (positifs correctement prédits sur tous les positifs prédits).                                                               | Quand minimiser les faux positifs est important (ex. alertes de sécurité).                              | Bonne : proche de 1 <br> Mauvaise : proche de 0 |
# | **F1-Score**   | Équilibrer la précision et le rappel dans un seul chiffre.                 | Moyenne harmonique entre précision et rappel : `2 * (Precision * Recall) / (Precision + Recall)`.                                                             | Quand il y a un compromis entre précision et rappel, notamment sur des données déséquilibrées.          | Bonne : proche de 1 <br> Mauvaise : proche de 0 |
# | **Kappa**      | Mesurer l'accord entre les prédictions et les vraies classes, ajusté au hasard. | Calculé comme : `(Accuracy - Chance Agreement) / (1 - Chance Agreement)`.                                                                                     | Pour évaluer la cohérence du modèle sur des données déséquilibrées.                                     | Bonne : proche de 1 <br> Mauvaise : proche de 0 (ou négative) |
# | **MCC**        | Fournir une mesure équilibrée même en cas de classes déséquilibrées.       | Calculé comme une corrélation : `(TP*TN - FP*FN) / sqrt((TP+FP)(TP+FN)(TN+FP)(TN+FN))`.                                                                       | Pour comparer des modèles sur des données très déséquilibrées.                                          | Bonne : proche de 1 <br> Mauvaise : proche de -1 ou 0 |
# | **TT (Sec)**   | Évaluer le temps nécessaire pour entraîner/tester un modèle.               | Mesuré en secondes.                                                                                                                                          | Quand le temps de calcul est critique, comme dans des systèmes en temps réel ou des applications embarquées. | Bonne : faible <br> Mauvaise : élevée |

# %% [markdown]
# Utiliser des métriques qui prennent en compte le déséquilibre des classes, comme :
#
# - F1-Score (harmonise précision et rappel),
# - AUC-ROC,
# - Matrice de confusion.
#
# Cela permet de mieux évaluer les performances sur la classe minoritaire.

# %% [markdown]
# ## <a id='toc7_2_'></a>[Comparatif des modèles avec PyCaret](#toc0_)

# %%
import pycaret
from pycaret.classification import *


# Initialiser l'environnement PyCaret
clf1 = setup(data=df[feature_scores[:15]['Feature']], target=Y,session_id=123, fix_imbalance=True)

# Comparer les modèles en fonction de l'AUC
best_model = compare_models(sort='AUC')

# Afficher le modèle avec la meilleure AUC
print(f"Le meilleur modèle basé sur l'AUC est : {best_model}")
# Out:
# <style type="text/css">
# #T_89f9d_row8_col1, #T_89f9d_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_89f9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89f9d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_89f9d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89f9d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89f9d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_89f9d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_89f9d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_89f9d_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_89f9d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_89f9d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_89f9d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_89f9d_row3_col1" class="data row3 col1" >(168317, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_89f9d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_89f9d_row4_col1" class="data row4 col1" >(266210, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_89f9d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_89f9d_row5_col1" class="data row5 col1" >(215714, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_89f9d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_89f9d_row6_col1" class="data row6 col1" >(50496, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_89f9d_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_89f9d_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_89f9d_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_89f9d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_89f9d_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_89f9d_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_89f9d_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_89f9d_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_89f9d_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_89f9d_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_89f9d_row12_col0" class="data row12 col0" >Fix imbalance</td>
#       <td id="T_89f9d_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_89f9d_row13_col0" class="data row13 col0" >Fix imbalance method</td>
#       <td id="T_89f9d_row13_col1" class="data row13 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_89f9d_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_89f9d_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_89f9d_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_89f9d_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_89f9d_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_89f9d_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_89f9d_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_89f9d_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_89f9d_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_89f9d_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_89f9d_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_89f9d_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_89f9d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_89f9d_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_89f9d_row20_col1" class="data row20 col1" >7a13</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e05d5 th {
#   text-align: left;
# }
# #T_e05d5_row0_col0, #T_e05d5_row0_col1, #T_e05d5_row0_col3, #T_e05d5_row0_col4, #T_e05d5_row0_col5, #T_e05d5_row1_col0, #T_e05d5_row1_col1, #T_e05d5_row1_col3, #T_e05d5_row1_col4, #T_e05d5_row2_col0, #T_e05d5_row2_col1, #T_e05d5_row2_col2, #T_e05d5_row2_col3, #T_e05d5_row2_col5, #T_e05d5_row2_col6, #T_e05d5_row2_col7, #T_e05d5_row3_col0, #T_e05d5_row3_col1, #T_e05d5_row3_col2, #T_e05d5_row3_col3, #T_e05d5_row3_col4, #T_e05d5_row3_col5, #T_e05d5_row3_col6, #T_e05d5_row3_col7, #T_e05d5_row4_col0, #T_e05d5_row4_col1, #T_e05d5_row4_col2, #T_e05d5_row4_col3, #T_e05d5_row4_col4, #T_e05d5_row4_col5, #T_e05d5_row4_col6, #T_e05d5_row4_col7, #T_e05d5_row5_col0, #T_e05d5_row5_col1, #T_e05d5_row5_col2, #T_e05d5_row5_col4, #T_e05d5_row5_col5, #T_e05d5_row5_col6, #T_e05d5_row5_col7, #T_e05d5_row6_col0, #T_e05d5_row6_col1, #T_e05d5_row6_col2, #T_e05d5_row6_col3, #T_e05d5_row6_col4, #T_e05d5_row6_col5, #T_e05d5_row6_col6, #T_e05d5_row6_col7, #T_e05d5_row7_col0, #T_e05d5_row7_col1, #T_e05d5_row7_col2, #T_e05d5_row7_col3, #T_e05d5_row7_col4, #T_e05d5_row7_col5, #T_e05d5_row7_col6, #T_e05d5_row7_col7, #T_e05d5_row8_col0, #T_e05d5_row8_col1, #T_e05d5_row8_col2, #T_e05d5_row8_col3, #T_e05d5_row8_col4, #T_e05d5_row8_col5, #T_e05d5_row8_col6, #T_e05d5_row8_col7, #T_e05d5_row9_col0, #T_e05d5_row9_col1, #T_e05d5_row9_col2, #T_e05d5_row9_col3, #T_e05d5_row9_col4, #T_e05d5_row9_col5, #T_e05d5_row9_col6, #T_e05d5_row9_col7, #T_e05d5_row10_col0, #T_e05d5_row10_col1, #T_e05d5_row10_col2, #T_e05d5_row10_col3, #T_e05d5_row10_col4, #T_e05d5_row10_col5, #T_e05d5_row10_col6, #T_e05d5_row10_col7, #T_e05d5_row11_col0, #T_e05d5_row11_col1, #T_e05d5_row11_col2, #T_e05d5_row11_col3, #T_e05d5_row11_col4, #T_e05d5_row11_col5, #T_e05d5_row11_col6, #T_e05d5_row11_col7, #T_e05d5_row12_col0, #T_e05d5_row12_col1, #T_e05d5_row12_col2, #T_e05d5_row12_col3, #T_e05d5_row12_col4, #T_e05d5_row12_col5, #T_e05d5_row12_col6, #T_e05d5_row12_col7, #T_e05d5_row13_col0, #T_e05d5_row13_col2, #T_e05d5_row13_col3, #T_e05d5_row13_col4, #T_e05d5_row13_col5, #T_e05d5_row13_col6, #T_e05d5_row13_col7 {
#   text-align: left;
# }
# #T_e05d5_row0_col2, #T_e05d5_row0_col6, #T_e05d5_row0_col7, #T_e05d5_row1_col2, #T_e05d5_row1_col5, #T_e05d5_row1_col6, #T_e05d5_row1_col7, #T_e05d5_row2_col4, #T_e05d5_row5_col3, #T_e05d5_row13_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e05d5_row0_col8, #T_e05d5_row1_col8, #T_e05d5_row2_col8, #T_e05d5_row3_col8, #T_e05d5_row4_col8, #T_e05d5_row5_col8, #T_e05d5_row6_col8, #T_e05d5_row7_col8, #T_e05d5_row8_col8, #T_e05d5_row9_col8, #T_e05d5_row10_col8, #T_e05d5_row11_col8, #T_e05d5_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e05d5_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e05d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e05d5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e05d5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e05d5_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e05d5_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e05d5_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e05d5_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e05d5_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e05d5_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_e05d5_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e05d5_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_e05d5_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_e05d5_row0_col1" class="data row0 col1" >0.6880</td>
#       <td id="T_e05d5_row0_col2" class="data row0 col2" >0.7415</td>
#       <td id="T_e05d5_row0_col3" class="data row0 col3" >0.6700</td>
#       <td id="T_e05d5_row0_col4" class="data row0 col4" >0.1663</td>
#       <td id="T_e05d5_row0_col5" class="data row0 col5" >0.2664</td>
#       <td id="T_e05d5_row0_col6" class="data row0 col6" >0.1515</td>
#       <td id="T_e05d5_row0_col7" class="data row0 col7" >0.2112</td>
#       <td id="T_e05d5_row0_col8" class="data row0 col8" >0.1260</td>
#     </tr>
#     <tr>
#       <th id="T_e05d5_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_e05d5_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_e05d5_row1_col1" class="data row1 col1" >0.6880</td>
#       <td id="T_e05d5_row1_col2" class="data row1 col2" >0.7415</td>
#       <td id="T_e05d5_row1_col3" class="data row1 col3" >0.6700</td>
#       <td id="T_e05d5_row1_col4" class="data row1 col4" >0.1663</td>
#       <td id="T_e05d5_row1_col5" class="data row1 col5" >0.2665</td>
#       <td id="T_e05d5_row1_col6" class="data row1 col6" >0.1515</td>
#       <td id="T_e05d5_row1_col7" class="data row1 col7" >0.2112</td>
#       <td id="T_e05d5_row1_col8" class="data row1 col8" >0.1720</td>
#     </tr>
#     <tr>
#       <th id="T_e05d5_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_e05d5_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e05d5_row2_col1" class="data row2 col1" >0.9141</td>
#       <td id="T_e05d5_row2_col2" class="data row2 col2" >0.7403</td>
#       <td id="T_e05d5_row2_col3" class="data row2 col3" >0.0237</td>
#       <td id="T_e05d5_row2_col4" class="data row2 col4" >0.3764</td>
#       <td id="T_e05d5_row2_col5" class="data row2 col5" >0.0445</td>
#       <td id="T_e05d5_row2_col6" class="data row2 col6" >0.0349</td>
#       <td id="T_e05d5_row2_col7" class="data row2 col7" >0.0765</td>
#       <td id="T_e05d5_row2_col8" class="data row2 col8" >1.6240</td>
#     </tr>
#     <tr>
#       <th id="T_e05d5_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_e05d5_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_e05d5_row3_col1" class="data row3 col1" >0.6866</td>
#       <td id="T_e05d5_row3_col2" class="data row3 col2" >0.7341</td>
#       <td id="T_e05d5_row3_col3" class="data row3 col3" >0.6550</td>
#       <td id="T_e05d5_row3_col4" class="data row3 col4" >0.1631</td>
#       <td id="T_e05d5_row3_col5" class="data row3 col5" >0.2612</td>
#       <td id="T_e05d5_row3_col6" class="data row3 col6" >0.1454</td>
#       <td id="T_e05d5_row3_col7" class="data row3 col7" >0.2024</td>
#       <td id="T_e05d5_row3_col8" class="data row3 col8" >4.1000</td>
#     </tr>
#     <tr>
#       <th id="T_e05d5_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_e05d5_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_e05d5_row4_col1" class="data row4 col1" >0.9036</td>
#       <td id="T_e05d5_row4_col2" class="data row4 col2" >0.7187</td>
#       <td id="T_e05d5_row4_col3" class="data row4 col3" >0.0810</td>
#       <td id="T_e05d5_row4_col4" class="data row4 col4" >0.2691</td>
#       <td id="T_e05d5_row4_col5" class="data row4 col5" >0.1245</td>
#       <td id="T_e05d5_row4_col6" class="data row4 col6" >0.0887</td>
#       <td id="T_e05d5_row4_col7" class="data row4 col7" >0.1071</td>
#       <td id="T_e05d5_row4_col8" class="data row4 col8" >4.9310</td>
#     </tr>
#     <tr>
#       <th id="T_e05d5_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_e05d5_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_e05d5_row5_col1" class="data row5 col1" >0.6094</td>
#       <td id="T_e05d5_row5_col2" class="data row5 col2" >0.7062</td>
#       <td id="T_e05d5_row5_col3" class="data row5 col3" >0.7018</td>
#       <td id="T_e05d5_row5_col4" class="data row5 col4" >0.1397</td>
#       <td id="T_e05d5_row5_col5" class="data row5 col5" >0.2330</td>
#       <td id="T_e05d5_row5_col6" class="data row5 col6" >0.1071</td>
#       <td id="T_e05d5_row5_col7" class="data row5 col7" >0.1704</td>
#       <td id="T_e05d5
# Le meilleur modèle basé sur l'AUC est : RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, positive=False, random_state=123, solver='auto',
#                 tol=0.0001)

# %% [markdown]
# ### <a id='toc7_2_1_'></a>[Anlayse du meilleur model](#toc0_)
#
# | **Métrique**      | **Valeur** | **Analyse**                                                                                                                                                                |
# |-------------------|------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Accuracy**      | 0.6880     | Une précision de **68.8%** peut sembler correcte, mais elle peut être trompeuse si les classes sont déséquilibrées. Le modèle peut prédire principalement la classe majoritaire.|
# | **AUC**           | 0.7415     | L'**AUC de 0.7415** indique que le modèle distingue modérément bien les classes. Toutefois, l'AUC seule ne suffit pas, surtout si le rappel et la précision sont faibles.    |
# | **Recall**        | 0.6700     | Le modèle identifie **67%** des vrais positifs, ce qui est acceptable mais reste modéré. Le modèle n'est pas totalement aveugle à la classe minoritaire.                     |
# | **Precision**     | 0.1663     | Une précision de **16.63%** est faible, indiquant que la majorité des prédictions positives sont des faux positifs. Cela pose problème pour des applications critiques.       |
# | **F1-Score**      | 0.2664     | Le **F1-score** de **0.2664** montre un déséquilibre entre précision et rappel. La faible précision impacte négativement l'efficacité globale du modèle.                      |
# | **Kappa**         | 0.1515     | Un **Kappa de 0.1515** indique un faible accord entre les prédictions et les vérités terrain, ce qui suggère que le modèle n'est pas beaucoup meilleur que le hasard.          |
# | **MCC**           | 0.2112     | Un **MCC faible (0.2112)** indique que le modèle a une corrélation modérée entre les prédictions et les vérités terrain, mais il n'est pas suffisant.                         |
# | **TT (Sec)**      | 0.1080     | Le **temps d'exécution** de **0.1080 s** est rapide, ce qui est un point positif pour des prédictions en temps réel ou dans des environnements où la rapidité est cruciale.     |

# %% [markdown]
# ### <a id='toc7_2_2_'></a>[Conclusion préliminaire :](#toc0_)
#
# Le modèle présente une base acceptable, mais nécessite des ajustements pour traiter les déséquilibres et optimiser ses performances. Il est important de prendre en compte ces aspects avant de déployer ce modèle dans un environnement réel.
